# %% [markdown]
# # Topic Modelling

# %% [markdown]
# **Data Science With Raghav**

# %% [markdown]
# **Youtube channel - https://www.youtube.com/channel/UC86OgfmVfguW69_0uIEffVQ/**

# %% [markdown]
# ### What is Topic Modelling?
#
# In my words Topic Modelling is the process of extracting major themes from a given corpus of text data.
#
# **Wikipedia Definition** <br>
# In machine learning and natural language processing, a topic model is a type of statistical model for discovering the abstract "topics" that occur in a collection of documents.
# <br><br>
# **Usage**<br>
# In the age of information, the amount of the written material we encounter each day is simply beyond our processing capacity. Topic models can help to organize and offer insights for us to understand large collections of unstructured text bodies.<br>
# Originally developed as a text-mining tool, topic models have also been used to detect instructive structures in data such as genetic information, images, and networks.<br>
#
# **History**<br>
# Original technique for topic modelling was developed in 1998 by Raghavan, Tamaki and Vempala. Then came the **PLSA (Probabilistic Latent Semantic Analysis)** in 1998 created by Thomas Hoffman.<br>
# Most commonly used technique called the <font color='green'>**LDA (Latent Drichilet Allocation)**</font> was developed in 2002 by Andrew Ng, David Blei and Michael Jordan. Another technique which is an extension of LDA is called the **Pachinko Allocation** and improves on LDA by modeling correlations between topics in addition to the word correlations which constitute topics.<br>
# An alternative to LDA is the **HLTA (Heirarchical Latent Tree Analysis)**, which models word co-occurrence using a tree of latent variables and the states of the latent variables, which correspond to soft clusters of documents, are interpreted as topics.

# %% [markdown]
# ## LDA - Latent Drichilet Allocation

# %% [markdown]
# **Dependenices**

# %%
# !pip install pyLDAvis

import pyLDAvis
import pyLDAvis.gensim_models

pyLDAvis.enable_notebook()

# %%
# !pip install pyLDAvis

import pyLDAvis
import pyLDAvis.gensim_models

pyLDAvis.enable_notebook()
# Out:
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.16)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.22.2.post1)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable
# /usr/local/lib/python3.7/dist-packages/past/builtins/misc.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Mapping
# /usr/local/lib/python3.7/dist-packages/scipy/fft/__init__.py:97: DeprecationWarning: The module numpy.dual is deprecated.  Instead of using dual, use the functions directly from numpy or scipy.
#   from numpy.dual import register_func
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/special/orthogonal.py:81: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from numpy import (exp, inf, pi, sqrt, floor, sin, cos, around, int,
# /usr/local/lib/python3.7/dist-packages/scipy/special/orthogonal.py:81: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from numpy import (exp, inf, pi, sqrt, floor, sin, cos, around, int,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:169: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:286: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_Gram=True, verbose=0,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:858: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True):
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:1094: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:1120: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:1349: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:1590: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:1723: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_lda.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps

# %%
# !python -m pip install -U gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Collecting gensim
#   Downloading gensim-4.1.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.0 MB)
#      |████████████████████████████████| 24.0 MB 89 kB/s
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.1.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.21.2)
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-4.1.0

# %%
#Dependencies
import pandas as pd
import gensim #the library for Topic modelling
from gensim.models.ldamulticore import LdaMulticore
from gensim import corpora, models
import pyLDAvis.gensim_models #LDA visualization library

from nltk.corpus import stopwords
import string
from nltk.stem.wordnet import WordNetLemmatizer

import warnings
warnings.simplefilter('ignore')
from itertools import chain
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# /usr/local/lib/python3.7/dist-packages/nltk/decorators.py:70: DeprecationWarning: `formatargspec` is deprecated since Python 3.5. Use `signature` and the `Signature` object directly
#   formatvalue=lambda value: "")[1:-1]
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/image.py:167: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int):
# /usr/local/lib/python3.7/dist-packages/scipy/io/matlab/mio5.py:98: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from .mio5_utils import VarReader5

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %% [markdown]
# ## own data

# %%
# !pip install pyLDAvis

import pyLDAvis
import pyLDAvis.gensim_models

pyLDAvis.enable_notebook()

# %%
# !pip install pyLDAvis

import pyLDAvis
import pyLDAvis.gensim_models

pyLDAvis.enable_notebook()
# Out:
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.16)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.22.2.post1)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable
# /usr/local/lib/python3.7/dist-packages/past/builtins/misc.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Mapping
# /usr/local/lib/python3.7/dist-packages/scipy/fft/__init__.py:97: DeprecationWarning: The module numpy.dual is deprecated.  Instead of using dual, use the functions directly from numpy or scipy.
#   from numpy.dual import register_func
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py:17: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
# /usr/local/lib/python3.7/dist-packages/scipy/special/orthogonal.py:81: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from numpy import (exp, inf, pi, sqrt, floor, sin, cos, around, int,
# /usr/local/lib/python3.7/dist-packages/scipy/special/orthogonal.py:81: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from numpy import (exp, inf, pi, sqrt, floor, sin, cos, around, int,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:169: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:286: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_Gram=True, verbose=0,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:858: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True):
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:1094: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:1120: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:1349: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:1590: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_least_angle.py:1723: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_lda.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps

# %%
# !python -m pip install -U gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Collecting gensim
#   Downloading gensim-4.1.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.0 MB)
#      |████████████████████████████████| 24.0 MB 89 kB/s
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.1.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.21.2)
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-4.1.0

# %%
#Dependencies
import pandas as pd
import gensim #the library for Topic modelling
from gensim.models.ldamulticore import LdaMulticore
from gensim import corpora, models
import pyLDAvis.gensim_models #LDA visualization library

from nltk.corpus import stopwords
import string
from nltk.stem.wordnet import WordNetLemmatizer

import warnings
warnings.simplefilter('ignore')
from itertools import chain
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# /usr/local/lib/python3.7/dist-packages/nltk/decorators.py:70: DeprecationWarning: `formatargspec` is deprecated since Python 3.5. Use `signature` and the `Signature` object directly
#   formatvalue=lambda value: "")[1:-1]
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/image.py:167: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int):
# /usr/local/lib/python3.7/dist-packages/scipy/io/matlab/mio5.py:98: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from .mio5_utils import VarReader5

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# p_test = pd.read_csv('TrainSA.csv')
# p_test.SentimentText=p_test.SentimentText.astype(str)

# %%
df = pd.read_csv('/content/gdrive/MyDrive/dev/Emails_analysis_labeled_utf8.CSV') 
# if encoding is latin-1 --> ,encoding='latin1'
# works without - , index_col=0 

df=df.astype(str)

# %%
# Convert first row of pandas dataframe to column name
# df.columns = df.iloc[0]

# %%
# old code
df["BetreffText"] =  df["Text"] + df["Betreff"]

# %%
# Combining Betreff and Text for single input of analysis
df["Analysis"] =  df["Text"] + df["Betreff"] + str(df["An: (Name)"]) + str(df["Von: (Name)"]) + str(df["CC: (Name)"])

# %%
df.head()
# Out:
#                                              Betreff  ...                                           Analysis
# 0  JF "Deep dive" GEHE AKADEMIE/ Sylvenstein - Of...  ...  Besprechueng offener Fragen/ weiterer Verlauef...
# 1  Re: NEueER Banner Lifescan // GEHE AKADEMIE //...  ...  Gueten Morgen Daniela,\r\nbin wieder zuerueck ...
# 2  Re: Bannerplatzierueng Ende Aueguest // Anfang...  ...  Schoenen gueten Morgen zuesammen, hi Maria,\r\...
# 3  AW: NEueER Banner Lifescan // GEHE AKADEMIE //...  ...  Hallo zuesammen, \r\n\r\n \r\n\r\nggf. koennte...
# 4                          WG: [EXTERNAL] Reportings  ...  Liebes Sylvenstein Team,\r\n\r\n \r\n\r\nbitte...
#
# [5 rows x 23 columns]

# %%
print(df.shape)
print(df)
# Out:
# (138, 23)
#                                                Betreff  ...                                           Analysis
# 0    JF "Deep dive" GEHE AKADEMIE/ Sylvenstein - Of...  ...  Besprechueng offener Fragen/ weiterer Verlauef...
# 1    Re: NEueER Banner Lifescan // GEHE AKADEMIE //...  ...  Gueten Morgen Daniela,\r\nbin wieder zuerueck ...
# 2    Re: Bannerplatzierueng Ende Aueguest // Anfang...  ...  Schoenen gueten Morgen zuesammen, hi Maria,\r\...
# 3    AW: NEueER Banner Lifescan // GEHE AKADEMIE //...  ...  Hallo zuesammen, \r\n\r\n \r\n\r\nggf. koennte...
# 4                            WG: [EXTERNAL] Reportings  ...  Liebes Sylvenstein Team,\r\n\r\n \r\n\r\nbitte...
# ..                                                 ...  ...                                                ...
# 133  [Sylvenstein SCRueM Team 1 - Auefgabe #672] (I...  ...  Sehr geehrtes Projektmitglied,\r\n\r\ndie Proj...
# 134  [Sylvenstein SCRueM Team 1 - Auefgabe #671] (N...  ...  Sehr geehrtes Projektmitglied,\r\n\r\ndie Proj...
# 135  [Sylvenstein SCRueM Team 1 - Auefgabe #670] (N...  ...  Sehr geehrtes Projektmitglied,\r\n\r\ndie Proj...
# 136  [Sylvenstein SCRueM Team 1 - Auefgabe #669] (N...  ...  Sehr geehrtes Projektmitglied,\r\n\r\ndie Proj...
# 137  [Sylvenstein SCRueM Team 1 - Featuere #612] (N...  ...  Sehr geehrtes Projektmitglied,\r\n\r\ndie Proj...
#
# [138 rows x 23 columns]

# %%
#clean the data
stop = set(stopwords.words('english','german'))
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()

def clean(text):
    stop_free = ' '.join([word for word in text.lower().split() if word not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = ' '.join([lemma.lemmatize(word) for word in punc_free.split()])
    return normalized.split()

# %%
df['text_clean']=df['Text'].apply(clean)

# %%
print(df.head())
# Out:
#                                              Betreff  ...                                         text_clean
# 0  JF "Deep dive" GEHE AKADEMIE/ Sylvenstein - Of...  ...  [besprechueng, offener, fragen, weiterer, verl...
# 1  Re: NEueER Banner Lifescan // GEHE AKADEMIE //...  ...  [gueten, morgen, daniela, bin, wieder, zueruec...
# 2  Re: Bannerplatzierueng Ende Aueguest // Anfang...  ...  [schoenen, gueten, morgen, zuesammen, hi, mari...
# 3  AW: NEueER Banner Lifescan // GEHE AKADEMIE //...  ...  [hallo, zuesammen, ggf, koennte, e, zue, verwi...
# 4                          WG: [EXTERNAL] Reportings  ...  [liebes, sylvenstein, team, bitte, senden, sie...
#
# [5 rows x 24 columns]

# %%
#create dictionary
dictionary = corpora.Dictionary(df['text_clean'])
#Total number of non-zeroes in the BOW matrix (sum of the number of unique words per document over the entire corpus).
print(dictionary.num_nnz)
# Out:
# 19625

# %%
#create document term matrix
doc_term_matrix = [dictionary.doc2bow(doc) for doc in df['text_clean'] ]
print(len(doc_term_matrix))
# Out:
# 138

# %%
# Instantiate LDA model
lda = gensim.models.ldamodel.LdaModel

# %%
# Fit LDA model on the dataset
num_topics=3
# %time ldamodel = lda(doc_term_matrix,num_topics=num_topics,id2word=dictionary,passes=50,minimum_probability=0)
# Out:
# CPU times: user 8.84 s, sys: 80.8 ms, total: 8.92 s
# Wall time: 8.86 s

# %%
# Print the topics identified by LDA model
ldamodel.print_topics(num_topics=num_topics)
# Out:
# [(0,
#   '0.016*"sie" + 0.015*"uend" + 0.014*"die" + 0.012*"der" + 0.009*"von" + 0.007*"werden" + 0.007*"da" + 0.006*"ich" + 0.006*"stuettgart" + 0.006*"e"'),
#  (1,
#   '0.009*"youe" + 0.007*"die" + 0.007*"daniela" + 0.006*"ues" + 0.006*"alliance" + 0.006*"49" + 0.006*"von" + 0.006*"miksch" + 0.006*"chris" + 0.005*"god"'),
#  (2,
#   '0.015*"von" + 0.013*"stuettgart" + 0.012*"49" + 0.011*"die" + 0.009*"0" + 0.008*"gehe" + 0.008*"giebel" + 0.008*"der" + 0.008*"vorsitzender" + 0.007*"sylvenstein"')]

# %%
# Visualize the LDA model results
# !pip install gensim
import gensim
from gensim import interfaces, utils, matutils
from gensim.matutils import dirichlet_expectation, mean_absolute_difference
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (4.1.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.21.2)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.1.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)

# %%
pip show pytest attrs
# Out:
# Name: pytest
# Version: 3.6.4
# Summary: pytest: simple powerful testing with Python
# Home-page: http://pytest.org
# Author: Holger Krekel, Bruno Oliveira, Ronny Pfannschmidt, Floris Bruynooghe, Brianna Laugher, Florian Bruhin and others
# Author-email: None
# License: MIT license
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: atomicwrites, six, more-itertools, pluggy, setuptools, py, attrs
# Required-by: datascience
# ---
# Name: attrs
# Version: 21.2.0
# Summary: Classes Without Boilerplate
# Home-page: https://www.attrs.org/
# Author: Hynek Schlawack
# Author-email: hs@ox.cx
# License: MIT
# Location: /usr/local/lib/python3.7/dist-packages
# Requires:
# Required-by: tensorflow-datasets, pytest

# %%
pip install folium==0.2.1
# Out:
# Collecting folium==0.2.1
#   Downloading folium-0.2.1.tar.gz (69 kB)
#      |████████████████████████████████| 69 kB 3.2 MB/s
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.7/dist-packages (from folium==0.2.1) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2->folium==0.2.1) (2.0.1)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.2.1-py3-none-any.whl size=79809 sha256=ed303333916939b4aad4210c9d21d9680f74954edb0f2917f55a047c246830ea
#   Stored in directory: /root/.cache/pip/wheels/9a/f0/3a/3f79a6914ff5affaf50cabad60c9f4d565283283c97f0bdccf
# Successfully built folium
# Installing collected packages: folium
#   Attempting uninstall: folium
#     Found existing installation: folium 0.8.3
#     Uninstalling folium-0.8.3:
#       Successfully uninstalled folium-0.8.3
# Successfully installed folium-0.2.1

# %%
pip install -U pytest
# Out:
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (6.2.5)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from pytest) (1.10.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from pytest) (0.10.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from pytest) (21.2.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest) (1.0.0)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest) (4.6.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytest) (21.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.7/dist-packages (from pytest) (1.1.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest) (3.5.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pytest) (2.4.7)

# %%
import re
import numpy as np
import pandas as  pd
from pprint import pprint# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel# spaCy for preprocessing
import spacy# Plotting tools
import pyLDAvis
import pyLDAvis.gensim_models
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install attrs==19.2.0
# Out:
# Collecting attrs==19.2.0
#   Downloading attrs-19.2.0-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 3.5 MB/s
# Installing collected packages: attrs
#   Attempting uninstall: attrs
#     Found existing installation: attrs 19.1.0
#     Uninstalling attrs-19.1.0:
#       Successfully uninstalled attrs-19.1.0
# Successfully installed attrs-19.2.0

# %%
file = url'https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css'
# Out:
#   File "<ipython-input-63-000b2a4a7733>", line 1
#     file = url'https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css'
#                                                                                               ^
# SyntaxError: invalid syntax

# %%
import pyLDAvis.urls as urls
urls('https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css')
files = {'/LDAvis.css': ["text/css", open(urls.LDAVIS_CSS_URL, 'r').read()]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-fc6c529c8a9d> in <module>()
#       1 import pyLDAvis.urls as urls
# ----> 2 urls('https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css')
#       3 files = {'/LDAvis.css': ["text/css", open(urls.LDAVIS_CSS_URL, 'r').read()]}
#
# TypeError: 'module' object is not callable

# %%
lda_display = pyLDAvis.gensim_models.prepare(ldamodel, doc_term_matrix, dictionary, sort_topics=False, mds='mmds')
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1561398617672180001650470014"></div>
# <script type="text/javascript">
#
# var ldavis_el1561398617672180001650470014_data = {"mdsDat": {"x": [0.0642191285402136, 0.1245878548943222, -0.18880698343453578], "y": [0.11029862393966029, -0.1219021161958226, 0.011603492256162327], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [23.572950335845306, 22.69374865576412, 53.733301008390576]}, "tinfo": {"Term": ["sie", "0", "youe", "uend", "giebel", "daniela", "god", "ues", "brauen", "miksch", "69", "christian", "chris", "nuember", "herr", "banner", "\u2013", "main", "frankfuert", "sylvenstein", "youer", "reporting", "95", "email", "231", "dortmuend", "ouer", "werden", "guenter", "die", "reporting", "emramed", "pauela", "dabei", "pantleon", "geliefert", "kohlpharma", "helligkeit", "auefgruend", "ad", "uentereinander", "ledallrouendleuechte", "dort", "vor", "b", "ihrer", "advertise", "confirm", "entsprechen", "darstellueng", "nochmals", "druecken", "darauef", "geben", "erfahre", "hoher", "feuechten", "httpsledkampanjinfomailwizzcampaignsga015blkxfb95trackuerlcb995z4jnl5cf97b8fdd4d53f6c461b5a51e8455d7c32559ec3d4", "hohen", "leistueng", "platziert", "position", "muessen", "weiter", "httpwwwgeheakademiede", "uenten", "sie", "ueber", "ob", "email", "uend", "danke", "haben", "wege", "informationen", "werden", "neuee", "youer", "auech", "zuesammen", "der", "die", "da", "e", "ich", "auef", "wir", "zue", "diese", "das", "ist", "uem", "von", "uenter", "stuettgart", "maria", "banner", "mit", "gehe", "ein", "nicht", "49", "den", "eine", "god", "nuember", "69", "main", "frankfuert", "healthcare", "buet", "jesues", "beast", "666", "revelation", "wwwalliancehealthcarede", "marketingmanagerin", "60486", "79203299", "79203524", "kuendenmanagement", "linkedin", "httpswwwlinkedincomcompanyalliancehealthcaredeuetschlandagviewasmembertruee", "follow", "vertriebs", "73", "httpswwwxingcomcompaniesalliancehealthcaredeuetschlandag", "xing", "httpwwwalliancehealthcarede", "solmsstrasse", "mark", "word", "kind", "holy", "deuetschland", "ouer", "miksch", "youe", "daniela", "ues", "chris", "banner", "guenter", "alliance", "alphegaseite", "mailtocgwacgde", "abouet", "maria", "die", "49", "uend", "der", "von", "youer", "ich", "den", "mit", "gmbh", "gehe", "2021", "stuettgart", "0", "brauen", "95", "231", "dortmuend", "neckartalstr", "join", "max", "veranstaltuengen", "sprint", "fortschritt", "\u2013", "left", "zuegewiesen", "servicedeskgehede", "uehlmann", "neue", "prioritaet", "ewald", "suepport", "354", "registergericht", "24489", "wwwseminarsoftwarede", "iris", "citrix", "desk", "geaendert", "httpwwwseminarsoftwarede", "nachricht", "giebel", "christian", "herr", "sylvenstein", "piehl", "thorsten", "thorstenpiehlgehede", "wuerde", "25", "kraiser", "vorsitzender", "thiede", "stuettgart", "von", "49", "geschaeftsfuehrer", "gesendet", "gmbh", "gehe", "hrb", "hallo", "de", "internal", "die", "mit", "der", "an", "711", "sie", "fuer", "uend"], "Freq": [230.0, 147.0, 87.0, 230.0, 142.0, 57.0, 40.0, 62.0, 98.0, 47.0, 36.0, 114.0, 61.0, 35.0, 112.0, 59.0, 93.0, 32.0, 32.0, 132.0, 57.0, 30.0, 79.0, 76.0, 78.0, 78.0, 34.0, 93.0, 51.0, 346.0, 30.389188572324635, 15.338870651831636, 13.66543837746384, 12.819501362886557, 11.992002600222254, 10.318567698699116, 10.318567698699116, 9.481864259432706, 9.445222448150686, 8.64512141283616, 8.641113249501762, 7.808427606472673, 8.588277652687808, 7.8003219565222315, 7.798931315627535, 6.971700522808181, 6.971683884157677, 6.971518373371092, 6.96086963704899, 6.960867447752872, 6.960863507019858, 6.912276020394925, 6.133260971719522, 6.111952990453948, 5.2982713134549515, 5.2982713134549515, 5.2982713134549515, 5.2982713134549515, 5.2982713134549515, 5.298270875595727, 30.401725357619636, 10.32087434108994, 13.409436100820312, 12.636876410680959, 11.746827706464126, 10.31916143580655, 122.81289884194689, 14.51612091030835, 15.570498181206302, 45.97809785817204, 112.830584258424, 19.609903646937163, 26.34410319674302, 13.660926676022108, 15.17725856377479, 50.20069311450717, 20.24439844235561, 33.1354696468 ...

# %% [markdown]
# **Find which articles were marked in which cluster**

# %%
# Assigns the topics to the documents in corpus
lda_corpus = ldamodel[doc_term_matrix]

# %%
[doc for doc in lda_corpus]
# Out:
# [[(0, 0.004207539), (1, 0.05157448), (2, 0.9442179)],
#  [(0, 0.00041022222), (1, 0.99916226), (2, 0.00042752107)],
#  [(0, 0.9979757), (1, 0.0010058379), (2, 0.0010184682)],
#  [(0, 0.00044633853), (1, 0.9987131), (2, 0.0008405616)],
#  [(0, 0.6512384), (1, 0.0008148364), (2, 0.34794676)],
#  [(0, 0.6570161), (1, 0.0010851021), (2, 0.3418988)],
#  [(0, 0.9979765), (1, 0.0009902099), (2, 0.0010333158)],
#  [(0, 0.9972032), (1, 0.0013379075), (2, 0.0014588789)],
#  [(0, 0.0027821525), (1, 0.0024859512), (2, 0.9947319)],
#  [(0, 0.6880339), (1, 0.0017561058), (2, 0.31021)],
#  [(0, 0.109573126), (1, 0.00576104), (2, 0.88466585)],
#  [(0, 0.98418385), (1, 0.0011941462), (2, 0.014622014)],
#  [(0, 0.06583838), (1, 0.004846582), (2, 0.92931503)],
#  [(0, 0.12417966), (1, 0.0016858209), (2, 0.87413454)],
#  [(0, 0.00037565816), (1, 0.0003631879), (2, 0.99926114)],
#  [(0, 0.0022235152), (1, 0.0021224136), (2, 0.9956541)],
#  [(0, 0.00043554115), (1, 0.0004204896), (2, 0.99914396)],
#  [(0, 0.0037931525), (1, 0.17316732), (2, 0.8230396)],
#  [(0, 0.005024083), (1, 0.0048865466), (2, 0.9900894)],
#  [(0, 0.0015489444), (1, 0.0013568432), (2, 0.99709415)],
#  [(0, 0.3680105), (1, 0.0013960891), (2, 0.6305934)],
#  [(0, 0.007424514), (1, 0.0070085763), (2, 0.985567)],
#  [(0, 0.0017373739), (1, 0.001575695), (2, 0.99668694)],
#  [(0, 0.0015236851), (1, 0.0014588684), (2, 0.99701744)],
#  [(0, 0.0022421589), (1, 0.0021584465), (2, 0.9955994)],
#  [(0, 0.004972676), (1, 0.004828011), (2, 0.99019927)],
#  [(0, 0.0044768127), (1, 0.004411933), (2, 0.9911113)],
#  [(0, 0.0059116534), (1, 0.0058530844), (2, 0.98823524)],
#  [(0, 0.28268734), (1, 0.0011507133), (2, 0.71616197)],
#  [(0, 0.0046516974), (1, 0.0045610666), (2, 0.9907872)],
#  [(0, 0.0043332996), (1, 0.0045041987), (2, 0.99116254)],
#  [(0, 0.003802492), (1, 0.0035196254), (2, 0.99267787)],
#  [(0, 0.0045350287), (1, 0.004453353), (2, 0.99101156)],
#  [(0, 0.0036007126), (1, 0.0032348484), (2, 0.9931645)],
#  [(0, 0.0032175358), (1, 0.0028205893), (2, 0.9939619)],
#  [(0, 0.0042079613), (1, 0.05157466), (2, 0.9442174)],
#  [(0, 0.00041305457), (1, 0.99914587), (2, 0.00044110088)],
#  [(0, 0.9979768), (1, 0.0010056245), (2, 0.0010175828)],
#  [(0, 0.00044631527), (1, 0.99858594), (2, 0.0009677478)],
#  [(0, 0.6512371), (1, 0.0008148364), (2, 0.3479481)],
#  [(0, 0.6570176), (1, 0.001085102), (2, 0.34189728)],
#  [(0, 0.99797636), (1, 0.00099021), (2, 0.0010334289)],
#  [(0, 0.9972033), (1, 0.0013379074), (2, 0.001458746)],
#  [(0, 0.0027840305), (1, 0.0024859514), (2, 0.99473)],
#  [(0, 0.68803644), (1, 0.0017561055), (2, 0.31020746)],
#  [(0, 0.109571874), (1, 0.005761044), (2, 0.88466716)],
#  [(0, 0.9842076), (1, 0.001194147), (2, 0.014598253)],
#  [(0, 0.06584199), (1, 0.0048465743), (2, 0.9293114)],
#  [(0, 0.124179885), (1, 0.0016858204), (2, 0.8741343)],
#  [(0, 0.00037563994), (1, 0.00036318804), (2, 0.99926114)],
#  [(0, 0.0022233701), (1, 0.002122413), (2, 0.99565417)],
#  [(0, 0.0004354222), (1, 0.00042048955), (2, 0.9991441)],
#  [(0, 0.003789959), (1, 0.1731691), (2, 0.8230409)],
#  [(0, 0.005023528), (1, 0.0048865466), (2, 0.99008995)],
#  [(0, 0.001549649), (1, 0.0013568434), (2, 0.99709344)],
#  [(0, 0.36801055), (1, 0.001396135), (2, 0.6305933)],
#  [(0, 0.0074296775), (1, 0.0070085814), (2, 0.9855618)],
#  [(0, 0.0017379763), (1, 0.0015756949), (2, 0.99668634)],
#  [(0, 0.001523625), (1, 0.0014588685), (2, 0.9970175)],
#  [(0, 0.0022424157), (1, 0.0021584472), (2, 0.9955991)],
#  [(0, 0.0049717976), (1, 0.0048280163), (2, 0.9902002)],
#  [(0, 0.0044770795), (1, 0.0044119554), (2, 0.991111)],
#  [(0, 0.005910589), (1, 0.0058529405), (2, 0.9882365)],
#  [(0, 0.28268668), (1, 0.0011507248), (2, 0.71616256)],
#  [(0, 0.00465267), (1, 0.0045610666), (2, 0.9907863)],
#  [(0, 0.0043333867), (1, 0.0045038746), (2, 0.9911627)],
#  [(0, 0.0038025444), (1, 0.0035196252), (2, 0.9926778)],
#  [(0, 0.0045323204), (1, 0.0044532525), (2, 0.9910144)],
#  [(0, 0.0036006263), (1, 0.0032348486), (2, 0.99316454)],
#  [(0, 0.0032132424), (1, 0.0028205912), (2, 0.9939662)],
#  [(0, 0.9891769), (1, 0.005725833), (2, 0.005097213)],
#  [(0, 0.9899576), (1, 0.004839934), (2, 0.005202519)],
#  [(0, 0.9725546), (1, 0.013328937), (2, 0.014116443)],
#  [(0, 0.7634341), (1, 0.23566732), (2, 0.0008985911)],
#  [(0, 0.99522334), (1, 0.002574461), (2, 0.0022021446)],
#  [(0, 0.9909566), (1, 0.0044029346), (2, 0.0046404595)],
#  [(0, 0.9959119), (1, 0.0021975774), (2, 0.0018904732)],
#  [(0, 0.02128332), (1, 0.95713335), (2, 0.021583276)],
#  [(0, 0.0048963865), (1, 0.99025774), (2, 0.004845834)],
#  [(0, 0.00014413123), (1, 0.9997129), (2, 0.00014292896)],
#  [(0, 0.5581608), (1, 0.43698773), (2, 0.0048514847)],
#  [(0, 0.99600273), (1, 0.0021985783), (2, 0.001798724)],
#  [(0, 0.99918145), (1, 0.0004026207), (2, 0.00041596632)],
#  [(0, 0.98322636), (1, 0.0082365135), (2, 0.008537104)],
#  [(0, 0.0017642453), (1, 0.0016533826), (2, 0.9965824)],
#  [(0, 0.9963727), (1, 0.0016989998), (2, 0.0019282501)],
#  [(0, 0.28112245), (1, 0.0042282045), (2, 0.7146494)],
#  [(0, 0.9349051), (1, 0.03143849), (2, 0.03365644)],
#  [(0, 0.9985699), (1, 0.0007044371), (2, 0.0007256204)],
#  [(0, 0.95038444), (1, 0.024190992), (2, 0.02542456)],
#  [(0, 0.9779477), (1, 0.012053437), (2, 0.009998886)],
#  [(0, 0.0030570338), (1, 0.9940083), (2, 0.0029347115)],
#  [(0, 0.0012704891), (1, 0.9975059), (2, 0.0012236245)],
#  [(0, 0.001697884), (1, 0.0015105427), (2, 0.9967916)],
#  [(0, 0.6643115), (1, 0.16822332), (2, 0.1674652)],
#  [(0, 0.0038327118), (1, 0.99239457), (2, 0.0037727663)],
#  [(0, 0.003258876), (1, 0.993633), (2, 0.003108177)],
#  [(0, 0.9867728), (1, 0.0064830133), (2, 0.0067441952)],
#  [(0, 0.0024289268), (1, 0.9953116), (2, 0.002259398)],
#  [(0, 0.97584575), (1, 0.011839701), (2, 0.012314574)],
#  [(0, 0.976577), (1, 0.011603473), (2, 0.011819578)],
#  [(0, 0.29563627), (1, 0.006187009), (2, 0.69817674)],
#  [(0, 0.61350256), (1, 0.0009051838), (2, 0.3855923)],
#  [(0, 0.0026572987), (1, 0.0025874774), (2, 0.9947552)],
#  [(0, 0.002657281), (1, 0.002649334), (2, 0.99469334)],
#  [(0, 0.0029587504), (1, 0.0029063108), (2, 0.9941349)],
#  [(0, 0.0022877078), (1, 0.0022107512), (2, 0.9955015)],
#  [(0, 0.0023637363), (1, 0.0022966708), (2, 0.99533963)],
#  [(0, 0.002740232), (1, 0.0027028916), (2, 0.9945569)],
#  [(0, 0.0038160826), (1, 0.0029599338), (2, 0.99322397)],
#  [(0, 0.001912572), (1, 0.0018805463), (2, 0.9962069)],
#  [(0, 0.0022604426), (1, 0.0022385395), (2, 0.99550104)],
#  [(0, 0.002139844), (1, 0.0020989417), (2, 0.99576116)],
#  [(0, 0.0024306362), (1, 0.002413625), (2, 0.9951557)],
#  [(0, 0.0027371533), (1, 0.002679483), (2, 0.99458337)],
#  [(0, 0.0025915864), (1, 0.0025580875), (2, 0.9948503)],
#  [(0, 0.002728417), (1, 0.0026258312), (2, 0.9946457)],
#  [(0, 0.0012820713), (1, 0.001224295), (2, 0.9974937)],
#  [(0, 0.00087386544), (1, 0.0008499838), (2, 0.9982762)],
#  [(0, 0.0008956148), (1, 0.0008707438), (2, 0.9982337)],
#  [(0, 0.0015592959), (1, 0.0015354168), (2, 0.99690527)],
#  [(0, 0.0020352043), (1, 0.0020299447), (2, 0.99593484)],
#  [(0, 0.0013350816), (1, 0.0012749449), (2, 0.99739003)],
#  [(0, 0.0015493856), (1, 0.0014662592), (2, 0.99698436)],
#  [(0, 0.0013059371), (1, 0.0012482138), (2, 0.9974458)],
#  [(0, 0.0023381782), (1, 0.0022739652), (2, 0.99538785)],
#  [(0, 0.0032195635), (1, 0.0032025906), (2, 0.99357784)],
#  [(0, 0.0011930276), (1, 0.0011853838), (2, 0.9976216)],
#  [(0, 0.0032238185), (1, 0.0032026814), (2, 0.9935735)],
#  [(0, 0.0017850924), (1, 0.0017729546), (2, 0.99644196)],
#  [(0, 0.0032239258), (1, 0.0032043115), (2, 0.99357176)],
#  [(0, 0.0018572414), (1, 0.0018508569), (2, 0.99629194)],
#  [(0, 0.0032181577), (1, 0.0032041767), (2, 0.9935777)],
#  [(0, 0.0016904613), (1, 0.0016740338), (2, 0.9966355)],
#  [(0, 0.0020061624), (1, 0.0019982343), (2, 0.9959956)],
#  [(0, 0.0019218748), (1, 0.0019077008), (2, 0.99617046)],
#  [(0, 0.0012525702), (1, 0.0012441233), (2, 0.99750334)],
#  [(0, 0.0034682634), (1, 0.0034608552), (2, 0.9930709)]]

# %%
scores = list(chain(*[[score for topic_id,score in topic] \
                      for topic in [doc for doc in lda_corpus]]))

threshold = sum(scores)/len(scores)
print(threshold)
# Out:
# 0.3333333331782535

# %%
cluster1 = [j for i,j in zip(lda_corpus,df.index) if i[0][1] > threshold]
cluster2 = [j for i,j in zip(lda_corpus,df.index) if i[1][1] > threshold]
cluster3 = [j for i,j in zip(lda_corpus,df.index) if i[2][1] > threshold]
# cluster4 = [j for i,j in zip(lda_corpus,df.index) if i[3][1] > threshold]
# cluster5 = [j for i,j in zip(lda_corpus,df.index) if i[4][1] > threshold]

print(len(cluster1))
print(len(cluster2))
print(len(cluster3))
# print(len(cluster4))
# print(len(cluster5))
# Out:
# 37
# 13
# 96

# %%
print(df.iloc[cluster1])
# Out:
#                                                Betreff  ...                                         text_clean
# 2    Re: Bannerplatzierueng Ende Aueguest // Anfang...  ...  [schoenen, gueten, morgen, zuesammen, hi, mari...
# 4                            WG: [EXTERNAL] Reportings  ...  [liebes, sylvenstein, team, bitte, senden, sie...
# 5                            AW: [EXTERNAL] Reportings  ...  [hallo, zuesammen, vielen, dank, fuer, die, re...
# 6    Re: Bannerplatzierueng Ende Aueguest // Anfang...  ...  [hallo, maria, ich, schauee, mir, da, montag, ...
# 7    WG: Bannerplatzierueng Ende Aueguest // Anfang...  ...  [hallo, zuesammen, wie, mittlerweile, bereits,...
# 9                  WG: Infos / uepdates zuem Reporting  ...  [von, schneil, goenna, mailtogoennaschneilgehe...
# 11                                 WG: [EXTERNAL] PDFs  ...  [goenna, schneil, leiterin, gehe, akademie, cu...
# 20               WG: GEHE AKADEMIE: Test SCORM-Dateien  ...  [hallo, herr, brauen, hallo, herr, fuehrmann, ...
# 37   Re: Bannerplatzierueng Ende Aueguest // Anfang...  ...  [schoenen, gueten, morgen, zuesammen, hi, mari...
# 39                           WG: [EXTERNAL] Reportings  ...  [liebes, sylvenstein, team, bitte, senden, sie...
# 40                           AW: [EXTERNAL] Reportings  ...  [hallo, zuesammen, vielen, dank, fuer, die, re...
# 41   Re: Bannerplatzierueng Ende Aueguest // Anfang...  ...  [hallo, maria, ich, schauee, mir, da, montag, ...
# 42   WG: Bannerplatzierueng Ende Aueguest // Anfang...  ...  [hallo, zuesammen, wie, mittlerweile, bereits,...
# 44                 WG: Infos / uepdates zuem Reporting  ...  [von, schneil, goenna, mailtogoennaschneilgehe...
# 46                                 WG: [EXTERNAL] PDFs  ...  [goenna, schneil, leiterin, gehe, akademie, cu...
# 55               WG: GEHE AKADEMIE: Test SCORM-Dateien  ...  [hallo, herr, brauen, hallo, herr, fuehrmann, ...
# 70   Email lists 100% VALID - Any couentry in the w...  ...  [get, best, email, list, youer, email, marketi...
# 71                                           Vorschlag  ...  [hallo, ich, bin, auefgruend, uenerwarteter, u...
# 72                                                 RE:  ...  [hallo, liebe, beguenstigte, sie, wuerden, aue...
# 73        YOueR COVID-19 FueND IS  READY FOR TRANSFER   ...  [uenited, nation, organization, 405, east, 42n...
# 74                 Advertise uep to 200 MILLION EMAILS  ...  [advertise, uep, 200, million, email, lowest, ...
# 75                                                  RE  ...  [hallo, sie, wuerden, auesgewaehlt, uem, eine,...
# 76        Great news for dispensaries and smoke shops!  ...  [oh, yeah, welcome, profitability, httpsseedle...
# 80                                          Mobile App  ...  [hello, woueld, youe, interested, bueild, mobi...
# 81                       Youer Ads Have Been Approved!  ...  [get, ready, scale, sale, duering, holiday, ht...
# 82   Achtueng: Sylvenstein Media GmbH, Letzter Tag ...  ...  [sollten, sie, diesis, email, nicht, ordentlic...
# 83                            Herzlichen Glueckwuensch  ...  [herzlichen, glueckwuensch, sie, haben, monatl...
# 85                                          ueBERTRAGT  ...  [buero, de, kopfes, internationaler, transfer,...
# 87          Final Warning: Mailbox Shuetdown Requeest   ...  [attention, ueser, confirm, email, activedate,...
# 88   Betreff: Ignorieren Sie diese E-Mail uend stel...  ...  [die, zweite, warnueng, sie, haben, meine, ers...
# 89   Attention : info@sylvenstein.com Access Confir...  ...  [id, infosylvensteincom, password, expires, 81...
# 90   Notification: info@sylvenstein.com  Password E...  ...  [ionos, 11, hi, info, youeve, many, held, inco...
# 94   ?uero 4,400 - ???/ ypge3wxqkpXkH00q3NdRDuekjCz...  ...                                              [nan]
# 97                                      € 2.130.000,00  ...  [hallo, ich, bin, tayeb, soueami, sie, haben, ...
# 99            Pending Message For info@sylvenstein.com  ...  [ionos, 11, we, are, cuerrently, doing, servic...
# 100                                        info Notice  ...  [sylvensteincom, we, are, cuerrently, donig, s...
# 102  [Sylvenstein SCRueM Team 1 - Featuere #765] (N...  ...  [sehr, geehrtes, projektmitglied, die, projekt...
#
# [37 rows x 24 columns]

# %%
print(df.iloc[cluster2])
# Out:
#                                               Betreff  ...                                         text_clean
# 1   Re: NEueER Banner Lifescan // GEHE AKADEMIE //...  ...  [gueten, morgen, daniela, bin, wieder, zueruec...
# 3   AW: NEueER Banner Lifescan // GEHE AKADEMIE //...  ...  [hallo, zuesammen, ggf, koennte, e, zue, verwi...
# 36  Re: NEueER Banner Lifescan // GEHE AKADEMIE //...  ...  [gueten, morgen, daniela, bin, wieder, zueruec...
# 38  AW: NEueER Banner Lifescan // GEHE AKADEMIE //...  ...  [hallo, zuesammen, ggf, koennte, e, zue, verwi...
# 77                     VM#09038674 from +493092323309  ...  [microsoft, volp, vmsg1, arrived, on, janueary...
# 78  How Atlantic Records discovers uep-and-coming ...  ...  [httpsairtable2intercommailcomqamxok2bvpeidsot...
# 79                                           Hi there  ...  [hi, there, best, wish, youe, youer, friend, f...
# 80                                         Mobile App  ...  [hello, woueld, youe, interested, bueild, mobi...
# 91                         Confidential Proposal,,     ...  [from, mr, francis, martin, chief, operating, ...
# 92                              Confidential Proposal  ...  [from, mr, francis, martin, chief, operating, ...
# 95                              SeminarCompanies.com   ...  [seminarcompaniescom, sale, hello, name, jovel...
# 96      SYLVENSTEIN.COM Web Certificate DELETE Notice  ...  [final, email, alert, youe, youer, invoice, no...
# 98               Social media for cannabis revealed..  ...  [yes, finally, figuered, ouer, social, cbd, th...
#
# [13 rows x 24 columns]

# %%
df.iloc[cluster3]
# Out:
#                                                Betreff  ...                                         text_clean
# 0    JF "Deep dive" GEHE AKADEMIE/ Sylvenstein - Of...  ...  [besprechueng, offener, fragen, weiterer, verl...
# 4                            WG: [EXTERNAL] Reportings  ...  [liebes, sylvenstein, team, bitte, senden, sie...
# 5                            AW: [EXTERNAL] Reportings  ...  [hallo, zuesammen, vielen, dank, fuer, die, re...
# 8                GEHE AKADEMIE: Teilnahmebestaetigueng  ...  [hallo, herr, giebel, hallo, herr, fuehrmann, ...
# 10                                    WG: Semi Problem  ...  [gueten, morgen, zuesammen, eine, kollegin, ha...
# ..                                                 ...  ...                                                ...
# 133  [Sylvenstein SCRueM Team 1 - Auefgabe #672] (I...  ...  [sehr, geehrtes, projektmitglied, die, projekt...
# 134  [Sylvenstein SCRueM Team 1 - Auefgabe #671] (N...  ...  [sehr, geehrtes, projektmitglied, die, projekt...
# 135  [Sylvenstein SCRueM Team 1 - Auefgabe #670] (N...  ...  [sehr, geehrtes, projektmitglied, die, projekt...
# 136  [Sylvenstein SCRueM Team 1 - Auefgabe #669] (N...  ...  [sehr, geehrtes, projektmitglied, die, projekt...
# 137  [Sylvenstein SCRueM Team 1 - Featuere #612] (N...  ...  [sehr, geehrtes, projektmitglied, die, projekt...
#
# [96 rows x 24 columns]

# %%
df.iloc[cluster4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-946077a8bdc1> in <module>()
# ----> 1 df.iloc[cluster4]
#
# NameError: name 'cluster4' is not defined

# %%
df.iloc[cluster5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-104dc9962fdb> in <module>()
# ----> 1 df.iloc[cluster5]
#
# NameError: name 'cluster5' is not defined

# %% [markdown]
# **Read News articles pickle file**

# %%
df = pd.read_pickle('/content/gdrive/MyDrive/dev/news_topic_modelling_0.pkl')
print(df.shape)
print(df)
# Out:
# (10, 2)
#     topic                                               text
# 0  corona  \n E-commerce companies can deliver essential ...
# 1  corona  \nGoa Chief Minister Pramod Sawant on Sunday s...
# 2  corona  \n Tamil Nadu has extended the coronavirus loc...
# 3  corona  \nSports complexes and stadia were on Sunday p...
# 4  corona  \nMaharashtra on Sunday reported 2,347 coronav...
# 5  iphone  \nThe news comes from Front Page Tech’s Jon Pr...
# 6  iphone  \nYou can count on death, taxes, and a steady ...
# 7  iphone  \nApple had been hoping to move past its recen...
# 8  iphone  \nThe iPhone 12 is supposed to deliver a small...
# 9  iphone  \nThanks to a flurry of exciting leaks, Apple’...

# %% [markdown]
# **Clean the data**

# %%
#clean the data
stop = set(stopwords.words('english'))
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()

def clean(text):
    stop_free = ' '.join([word for word in text.lower().split() if word not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = ' '.join([lemma.lemmatize(word) for word in punc_free.split()])
    return normalized.split()

# %%
df['text_clean']=df['text'].apply(clean)

# %% [markdown]
# **Dataframe after cleaning**

# %%
print(df)
# Out:
#     topic  ...                                         text_clean
# 0  corona  ...  [ecommerce, company, deliver, essential, nones...
# 1  corona  ...  [goa, chief, minister, pramod, sawant, sunday,...
# 2  corona  ...  [tamil, nadu, extended, coronavirus, lockdown,...
# 3  corona  ...  [sport, complex, stadium, sunday, permitted, o...
# 4  corona  ...  [maharashtra, sunday, reported, 2347, coronavi...
# 5  iphone  ...  [news, come, front, page, tech’s, jon, prosser...
# 6  iphone  ...  [count, death, tax, steady, stream, shiny, new...
# 7  iphone  ...  [apple, hoping, move, past, recent, run, secur...
# 8  iphone  ...  [iphone, 12, supposed, deliver, smaller, notch...
# 9  iphone  ...  [thanks, flurry, exciting, leak, apple’s, ipho...
#
# [10 rows x 3 columns]

# %% [markdown]
# **Create Dictionary from the articles**

# %%
#create dictionary
dictionary = corpora.Dictionary(df['text_clean'])
#Total number of non-zeroes in the BOW matrix (sum of the number of unique words per document over the entire corpus).
print(dictionary.num_nnz)
# Out:
# 2130

# %% [markdown]
# **Create document term matrix**

# %%
#create document term matrix
doc_term_matrix = [dictionary.doc2bow(doc) for doc in df['text_clean'] ]
print(len(doc_term_matrix))
# Out:
# 10

# %% [markdown]
# **Instantiate LDA model**

# %%
# Instantiate LDA model
lda = gensim.models.ldamodel.LdaModel

# %% [markdown]
# **Fit LDA model on the dataset**

# %%
# Fit LDA model on the dataset
num_topics=3
# %time ldamodel = lda(doc_term_matrix,num_topics=num_topics,id2word=dictionary,passes=50,minimum_probability=0)
# Out:
# CPU times: user 802 ms, sys: 3.25 ms, total: 806 ms
# Wall time: 808 ms

# %% [markdown]
# **Print the topics identified by LDA model**

# %%
# Print the topics identified by LDA model
ldamodel.print_topics(num_topics=num_topics)
# Out:
# [(0,
#   '0.039*"iphone" + 0.020*"apple" + 0.013*"12" + 0.009*"new" + 0.007*"would" + 0.007*"prosser" + 0.007*"charging" + 0.006*"11" + 0.006*"portless" + 0.006*"state"'),
#  (1,
#   '0.010*"io" + 0.010*"said" + 0.009*"security" + 0.008*"state" + 0.008*"user" + 0.008*"zone" + 0.007*"lockdown" + 0.007*"exploit" + 0.007*"allowed" + 0.006*"sunday"'),
#  (2,
#   '0.015*"ipad" + 0.011*"tap" + 0.010*"app" + 0.009*"apple" + 0.009*"click" + 0.008*"device" + 0.008*"use" + 0.007*"screen" + 0.007*"free" + 0.006*"old"')]

# %% [markdown]
# **Visualize the LDA model results**

# %%
# Visualize the LDA model results
# !pip install gensim
import gensim
from gensim import interfaces, utils, matutils
from gensim.matutils import dirichlet_expectation, mean_absolute_difference
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (4.1.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.1.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.21.2)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)

# %%
pip show pytest attrs
# Out:
# Name: pytest
# Version: 3.6.4
# Summary: pytest: simple powerful testing with Python
# Home-page: http://pytest.org
# Author: Holger Krekel, Bruno Oliveira, Ronny Pfannschmidt, Floris Bruynooghe, Brianna Laugher, Florian Bruhin and others
# Author-email: None
# License: MIT license
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: pluggy, more-itertools, attrs, py, atomicwrites, six, setuptools
# Required-by: datascience
# ---
# Name: attrs
# Version: 21.2.0
# Summary: Classes Without Boilerplate
# Home-page: https://www.attrs.org/
# Author: Hynek Schlawack
# Author-email: hs@ox.cx
# License: MIT
# Location: /usr/local/lib/python3.7/dist-packages
# Requires:
# Required-by: tensorflow-datasets, pytest

# %%
pip install -U pytest
# Out:
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (3.6.4)
# Collecting pytest
#   Downloading pytest-6.2.5-py3-none-any.whl (280 kB)
#      |████████████████████████████████| 280 kB 2.6 MB/s
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest) (4.6.4)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from pytest) (0.10.2)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from pytest) (1.10.0)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytest) (21.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from pytest) (21.2.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.7/dist-packages (from pytest) (1.1.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest) (3.5.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pytest) (2.4.7)
# Installing collected packages: pluggy, pytest
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: pytest
#     Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed pluggy-1.0.0 pytest-6.2.5

# %%
import re
import numpy as np
import pandas as  pd
from pprint import pprint# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel# spaCy for preprocessing
import spacy# Plotting tools
import pyLDAvis
import pyLDAvis.gensim_models
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install attrs==19.1.0
# Out:
# Collecting attrs==19.1.0
#   Downloading attrs-19.1.0-py2.py3-none-any.whl (35 kB)
# Installing collected packages: attrs
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.2.0
#     Uninstalling attrs-21.2.0:
#       Successfully uninstalled attrs-21.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytest 6.2.5 requires attrs>=19.2.0, but you have attrs 19.1.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed attrs-19.1.0

# %%
lda_display = pyLDAvis.gensim_models.prepare(ldamodel, doc_term_matrix, dictionary, sort_topics=False, mds='mmds')
pyLDAvis.show(lda_display)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-c6e6381ebd51> in <module>()
#       1 lda_display = pyLDAvis.gensim_models.prepare(ldamodel, doc_term_matrix, dictionary, sort_topics=False, mds='mmds')
# ----> 2 pyLDAvis.show(lda_display)
#
# /usr/local/lib/python3.7/dist-packages/pyLDAvis/_display.py in show(data, ip, port, n_retries, local, open_browser, http_server, **kwargs)
#     260         kwargs['ldavis_css_url'] = urls.LDAVIS_CSS_URL
#     261         files = {'/LDAvis.js': ["text/javascript", open(urls.LDAVIS_LOCAL, 'r').read()],
# --> 262                  '/LDAvis.css': ["text/css", open(urls.LDAVIS_CSS_URL, 'r').read()],
#     263                  '/d3.js': ["text/javascript", open(urls.D3_URL, 'r').read()]}
#     264     html = prepared_data_to_html(data, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css'

# %% [markdown]
# **Find which articles were marked in which cluster**

# %%
# Assigns the topics to the documents in corpus
lda_corpus = ldamodel[doc_term_matrix]

# %%
[doc for doc in lda_corpus]
# Out:
# [[(0, 0.0018534273), (1, 0.99635816), (2, 0.0017884288)],
#  [(0, 0.0021954428), (1, 0.99567735), (2, 0.0021272046)],
#  [(0, 0.99756366), (1, 0.0012790913), (2, 0.0011572256)],
#  [(0, 0.0017647956), (1, 0.9964985), (2, 0.0017366648)],
#  [(0, 0.5190988), (1, 0.478511), (2, 0.0023902126)],
#  [(0, 0.997987), (1, 0.000995337), (2, 0.0010176582)],
#  [(0, 0.00050553516), (1, 0.0004940317), (2, 0.99900043)],
#  [(0, 0.0008229196), (1, 0.998358), (2, 0.00081906805)],
#  [(0, 0.9976776), (1, 0.0011465302), (2, 0.0011758785)],
#  [(0, 0.99860775), (1, 0.0006909684), (2, 0.0007012857)]]

# %%
scores = list(chain(*[[score for topic_id,score in topic] \
                      for topic in [doc for doc in lda_corpus]]))

threshold = sum(scores)/len(scores)
print(threshold)
# Out:
# 0.33333333211097244

# %%
cluster1 = [j for i,j in zip(lda_corpus,df.index) if i[0][1] > threshold]
cluster2 = [j for i,j in zip(lda_corpus,df.index) if i[1][1] > threshold]
cluster3 = [j for i,j in zip(lda_corpus,df.index) if i[2][1] > threshold]
# cluster4 = [j for i,j in zip(lda_corpus,df.index) if i[3][1] > threshold]
# cluster5 = [j for i,j in zip(lda_corpus,df.index) if i[4][1] > threshold]

print(len(cluster1))
print(len(cluster2))
print(len(cluster3))
# print(len(cluster4))
# print(len(cluster5))
# Out:
# 5
# 5
# 1

# %%
print(df.iloc[cluster1])
# Out:
#     topic  ...                                         text_clean
# 2  corona  ...  [tamil, nadu, extended, coronavirus, lockdown,...
# 4  corona  ...  [maharashtra, sunday, reported, 2347, coronavi...
# 5  iphone  ...  [news, come, front, page, tech’s, jon, prosser...
# 8  iphone  ...  [iphone, 12, supposed, deliver, smaller, notch...
# 9  iphone  ...  [thanks, flurry, exciting, leak, apple’s, ipho...
#
# [5 rows x 3 columns]

# %%
print(df.iloc[cluster2])
# Out:
#     topic  ...                                         text_clean
# 0  corona  ...  [ecommerce, company, deliver, essential, nones...
# 1  corona  ...  [goa, chief, minister, pramod, sawant, sunday,...
# 3  corona  ...  [sport, complex, stadium, sunday, permitted, o...
# 4  corona  ...  [maharashtra, sunday, reported, 2347, coronavi...
# 7  iphone  ...  [apple, hoping, move, past, recent, run, secur...
#
# [5 rows x 3 columns]

# %%
df.iloc[cluster3]
# Out:
#     topic  ...                                         text_clean
# 6  iphone  ...  [count, death, tax, steady, stream, shiny, new...
#
# [1 rows x 3 columns]

# %%
df.iloc[cluster4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-946077a8bdc1> in <module>()
# ----> 1 df.iloc[cluster4]
#
# NameError: name 'cluster4' is not defined

# %%
df.iloc[cluster5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-104dc9962fdb> in <module>()
# ----> 1 df.iloc[cluster5]
#
# NameError: name 'cluster5' is not defined
