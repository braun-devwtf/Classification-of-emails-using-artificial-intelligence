# %%
engine = create_engine("dialect+driver://username:password@host:port/database")

# %%
# !curl ipecho.net/plain
# Get Ip of this NoteBook 
# and authorize at google.cloud:

# gcloud sql instances patch semi-interface-mysql \--authorized-networks=34.125.147.53,93.198.190.167
# Out:
# 34.125.26.201

# %%
pip install sqlalchemy

# %%
pip install mysqlclient
# Out:
# ...
#      |████████████████████████████████| 88 kB 4.4 MB/s
# ...
#   Created wheel for mysqlclient: filename=mysqlclient-2.0.3-cp37-cp37m-linux_x86_64.whl size=100137 sha256=b37c51088cac130cfcfdec4fde2378bea3869f08230b3e4f781a4fa8095de650
#   Stored in directory: /root/.cache/pip/wheels/79/1c/f8/11fafab45fe6696eea63794a5d747b9c6b54990ac6f1885fb7
# Successfully built mysqlclient
# ...

# %%
# old Code
# Connect googleDrive

# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import MySQLdb
import sqlalchemy
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine("mysql://root:fyqsYm-0jashy-sitsuv@35.222.253.9/emails",echo = True)

# %% [markdown]
# ## TO MySQL

# %%
# TO SQL

# ReCreates Table - uses Dataframe 
# at given connection

# so Data should be cleand before importing to MySQL 
# another script that just adds data is needed for production

df = pd.read_csv('/content/drive/MyDrive/dev/Emails_analysis_unlabeled_latin1_new.CSV', encoding="utf-8") 
# if encoding is latin-1 --> ,encoding='latin1'
# works without - , index_col=0 

# Combining Betreff and Text for single input of analysis
df.fillna('NULL',inplace=True)
df["Analysis"] = df["Betreff"] + df["Text"]+ df["Tags"]


engine = create_engine("mysql://root:fyqsYm-0jashy-sitsuv@35.222.253.9/emails",echo = True)
df.to_sql("##EmailsUtf8Raw", con=engine, if_exists='replace',)

# %% [markdown]
# ## MySQL Connection with SQL Alchemy
#
# containing:
#
# *   pip install
# *   imports
# *   Scripts:
#     * TO MySQL
#     * FROM MySQL
#
#
#
# ```
# # SQLAlchemy connectable
# engine = create_engine("mysql://root:fyqsYm-0jashy-sitsuv@35.222.253.9/emails",echo = True)
#
# # FROM SQL
# df = pd.read_sql_table('##EmailsLabeledCleanedKeywordsPredTags', engine)
#
# # TO SQL
# df.to_sql("##EmailsUtf8", con=engine, if_exists='replace',)
# ```

# %%
pip install mysqlclient

# %%
pip install sqlalchemy

# %%
import pandas as pd 
from sqlalchemy import create_engine

# %%
# FROM SQL

# import the modules
import pandas as pd 
from sqlalchemy import create_engine
  
# SQLAlchemy connectable
engine = create_engine("mysql://root:fyqsYm-0jashy-sitsuv@35.222.253.9/emails",echo = True)
  
# table named 'contacts' will be returned as a dataframe.
df = pd.read_sql_table('EmailsUtf8Raw', engine)

# %%
# TO SQL

# ReCreates Table - uses Dataframe 
# at given connection

# so Data should be cleand before importing to MySQL 
# another script that just adds data is needed for production

df = pd.read_csv('/content/drive/MyDrive/dev/Emails_analysis_unlabeled_latin1_new.CSV', encoding="utf-8") 
# if encoding is latin-1 --> ,encoding='latin1'
# works without - , index_col=0 

# Combining Betreff and Text for single input of analysis
#df["Analysis"] = df["Betreff"] + df["Text"]+ df["Tags"]

engine = create_engine("mysql://root:fyqsYm-0jashy-sitsuv@35.222.253.9/emails",echo = True)
df.to_sql("EmailsUtf8Raw", con=engine, if_exists='replace',)

# %%
#engine = sqlalchemy.create_engine('mssql://NOT_MyServer/DB_People?Driver=SQL+Server+Native+Client+11.0?trusted_connection=yes')

#df.to_sql("##People Table")

# %%
# /content/drive/MyDrive/dev/Philipp.CSV

# %%
#philippEmails = pd.read_csv('/content/drive/MyDrive/dev/Philipp.CSV', encoding='latin-1')

# %%
#df = pd.read_csv('/content/drive/MyDrive/dev/Emails_analysis_unlabeled_latin1_new.CSV')

# %%
# Combining Betreff and Text for single input of analysis
# df["Analysis"] = df["Betreff"] + df["Text"]+ df["Tags"]

# %%
#df.head()

# %% [markdown]
# ## Not Working connection trials

# %%
from sqlalchemy.types import Integer, Text, String, DateTime

table_name = 'EmailsPhilipp'

jobs_df.to_sql(
    table_name,
    engine,
    if_exists='replace',
    index=False,
    chunksize=500,
    dtype={
        "job_id": Integer,
        "agency": Text,
        "business_title": Text,
        "job_category":  Text,
        "salary_range_from": Integer,
        "salary_range_to": Integer,
        "salary_frequency": String(50),
        "work_location": Text,
        "division/work_unit": Text,
        "job_description": Text,
        "posting_date": DateTime,
        "posting_updated": DateTime
    }
)

# %%
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String
engine = create_engine("mysql://root:fyqsYm-0jashy-sitsuv@35.222.253.9/emails",echo = True)
meta = MetaData()

emails = Table(
   'emails', meta, 
   Column('id', Integer, primary_key = True), 
   Column('Betreff', String(1000)), 
   Column('Text', String(1000)),
   Column('Von:Name', String(1000)),
   Column('Von:Adresse', String(1000)),
   Column('Von:Typ', String(1000)),
   Column('an:Name', String(1000)),
   Column('an:Adresse', String(1000)),
   Column('an:Typ', String(1000)),
   Column('CC:Name', String(1000)),
   Column('CC:Adresse', String(1000)),
   Column('CC: (Typ)', String(1000)),

   Column('BCC: (Name)', String(1000)),
   Column('BCC: (Adresse)', String(1000)),
   Column('BCC: (Typ)', String(1000)),

   Column('Abrechnungsinformationen', String(1000)),

   Column('Kategorien', String(1000)),
   Column('Reisekilometer', String(1000)),
   Column('Vertraulichkeit', String(1000)),
   Column('Wichtigkeit', String(1000)),


)
meta.create_all(engine)
# Out:
# 2021-09-06 12:07:52,560 INFO sqlalchemy.engine.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2021-09-06 12:07:52,562 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-06 12:07:52,570 INFO sqlalchemy.engine.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2021-09-06 12:07:52,572 INFO sqlalchemy.engine.Engine [generated in 0.00278s] ()
# 2021-09-06 12:07:52,581 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2021-09-06 12:07:52,582 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-06 12:07:52,590 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-06 12:07:52,592 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %s AND table_name = %s
# 2021-09-06 12:07:52,594 INFO sqlalchemy.engine.Engine [generated in 0.00156s] ('emails', 'emails')
# 2021-09-06 12:07:52,597 INFO sqlalchemy.engine.Engine COMMIT

# %%
from sqlalchemy import text
t = text("SELECT * FROM EmailsUtf8")
result = engine.execute(t)

# %%
# %%sh
# wget https://dl.google.com/cloudsql/cloud_sql_proxy.linux.amd64 -O cloud_sql_proxy

# %%
# %%sh
# chmod +x cloud_sql_proxy

# %%
# %%sh
# sqlcmd -S tcp:35.228.11.25,1433 -U USERNAME -P PASSWORD
# Out:
# sh: 1: sqlcmd: not found

# %%
pip install PyMySQL
# Out:
# ...
#      |████████████████████████████████| 43 kB 1.0 MB/s
# ...

# %%
pip install mysql-connector-python
# Out:
# ...
#      |████████████████████████████████| 30.9 MB 78 kB/s
# ...

# %%
import sqlite3
from google.cloud import storage
import pandas as pd
import numpy as np 
from datetime import datetime
import mysql.connector
import sys

# %%
#host="35.228.11.25", user="sqlserver",passwd="wabSet-hakmyr-3sebmo", db="emails")

# %%
cnx = mysql.connector.connect(user='root', password='fyqsYm-0jashy-sitsuv', host='35.222.253.9', database='emails')
cursor = cnx.cursor()

query = "select * from emails"
cursor.execute(query)
frame = dp.DataFrame(cursor.fetchall())
frame
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     515                                raw_as_string=raw_as_string,
# --> 516                                query_attrs=self._query_attrs)
#     517         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Table 'emails.emails' doesn't exist
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-62-9e9833cc37ab> in <module>()
#       3
#       4 query = "select * from emails"
# ----> 5 cursor.execute(query)
#       6 frame = dp.DataFrame(cursor.fetchall())
#       7 frame
#
# ...

# %% [markdown]
# ## Not working - SQL Server 2014 interface
#
# > Eingerückter Textblock

# %%
pip install pyodbc

# %%
import pyodbc
#import os

# %%
pip install sqlserverport

# %%
# %%sh
# curl https://packages.microsoft.com/keys/microsoft.asc | apt-key add -
# curl https://packages.microsoft.com/config/ubuntu/16.04/prod.list > /etc/apt/sources.list.d/mssql-release.list
# sudo apt-get update
# sudo ACCEPT_EULA=Y apt-get -q -y install msodbcsql17

# %%
# Check for drivers
for driver in pyodbc.drivers():
  print(driver)
# Out:
# ODBC Driver 17 for SQL Server

# %%
pyodbc.drivers()
# Out:
# ['ODBC Driver 17 for SQL Server']

# %%
# %%sh
# #cat /etc/odbcinst.ini

# %%
# %%sh
# #register the SQL Server database DSN information in /etc/odbc.ini
# sudo odbcinst -i -s -f /MSSQLServerDatabase.txt -l

# %%
# %%sh
# # check the DSN installation with:
# cat /etc/odbc.ini   # should contain a section called [MSSQLServerDatabase]

# %%
pyodbc.connect('DSN=MSSQLServerDatabase;UID=Sylvenstein009;PWD=Sylvenstein2020!')

# %%
import pyodbc
import sqlserverport 
servername = '85.214.143.93'
serverspec = '{0},{1}'.format(
    servername,
    sqlserverport.lookup(servername, 'SQLEXPRESS'))
conn = pyodbc.connect('DRIVER=ODBC Driver 17 for SQL Server;SERVER={};...'.format(serverspec))

# %%
pip install sqlserverport

# %%
#example.py
import sqlserverport

# test data
server_name = "35.222.253.9"
instance_name = "semi-interface-mysql"

try:
    result = r"Instance {0}\{1} is listening on port {2}.".format(
        server_name,
        instance_name,
        sqlserverport.lookup(server_name, instance_name),
    )
except sqlserverport.BrowserError as err:
    result = err.message
except sqlserverport.NoTcpError as err:
    result = err.message

print(result)
# Out:
# No response from the SQL Browser service. Verify that the service is available on 35.222.253.9 and \semi-interface-mysql is a valid instance name on it.

# %%
conn = pyodbc.connect(DRIVER = '{ODBC Driver 17 for SQL Server}',
                      SERVER = '85.214.143.93',
                      DATABASE = 'Semi_Interface',
                      UID='Administartor',
                      PWD='F6pkzr49'

                      )

cursor = conn.cursor()

# %%
# %%sh
# apt-get install krb5-user

# %%
conn = pyodbc.connect('Driver={ODBC Driver 17 for SQL Server};'
                      'Server=85.214.143.93,1433;'
                      'Database=Semi_Interface;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-13-61e074b69c27> in <module>()
# ----> 1 conn = pyodbc.connect('Driver={ODBC Driver 17 for SQL Server};'
#       2                       'Server=85.214.143.93,1433;'
#       3                       'Database=Semi_Interface;'
#       4                       'Trusted_Connection=yes;')
#       5
#
# Error: ('HY000', '[HY000] [unixODBC][Microsoft][ODBC Driver 17 for SQL Server]SSPI Provider: No Kerberos credentials available (default cache: FILE:/tmp/krb5cc_0) (851968) (SQLDriverConnect)')

# %%
#Server=DESKTOP-F8CV74C\SQLEXPRESSSEMI;Database=myDataBase;User Id=myUsername;Password=myPassword;

# %%
server = 'H2871513\SQLEXPRESS'
database = 'Semi_Interface'

conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};\
                       Server=' + server + ';\
                       DATABASE=' + database + ';\
                       Trusted_Connection=yes;')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-38-fe1979c4ca04> in <module>()
#       2 database = 'Semi_Interface'
#       3
# ----> 4 conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};                       Server=' + server + ';                       DATABASE=' + database + ';                       Trusted_Connection=yes;')
#
# OperationalError: ('HYT00', '[HYT00] [unixODBC][Microsoft][ODBC Driver 17 for SQL Server]Login timeout expired (0) (SQLDriverConnect)')

# %%
server = 'H2871513\SQLEXPRESS'
database = 'Semi_Interface'

conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};\
                       Server=' + server + ';\
                       DATABASE=' + database + ';\
                       UID=Administartor;\
                       PWD=F6pkzr49;)
# Out:
#   File "<ipython-input-37-e83df1993ef8>", line 4
#     conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};                       Server=' + server + ';                       DATABASE=' + database + ';                       UID=Administartor;                       PWD=F6pkzr49;)
#                                                                                                                                                                                                                                               ^
# SyntaxError: EOL while scanning string literal

# %%
cnxn = pyodbc.connect('driver={ODBC Driver 17 for SQL Server};Server=H2871513\SQLEXPRESS, 1433;'.

# %%
SQLdbconnection = pyodbc.connect(r'DRIVER={ODBC Driver 17 for SQL Server};SERVER=H2871513\SQLEXPRESS;DATABASE=Semi_Interface;UID=Administartor;PWD=F6pkzr49')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-39-5d3c48dbe80b> in <module>()
# ----> 1 SQLdbconnection = pyodbc.connect(r'DRIVER={ODBC Driver 17 for SQL Server};SERVER=H2871513\SQLEXPRESS;DATABASE=Semi_Interface;UID=Administartor;PWD=F6pkzr49')
#
# OperationalError: ('HYT00', '[HYT00] [unixODBC][Microsoft][ODBC Driver 17 for SQL Server]Login timeout expired (0) (SQLDriverConnect)')

# %%
server = '85.214.143.93,1433' 
database = 'Semi_Interface' 
username = 'H2871513\Administrator' 
password = 'F6pkzr49' 
cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/lib/python3.7/encodings/utf_16_le.py in decode(input, errors)
#      14
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_16_le_decode(input, errors, True)
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt: decoding with 'utf-16le' codec failed (KeyboardInterrupt: )
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-43-fb2806f2dc42> in <module>()
#       3 username = 'H2871513\Administrator'
#       4 password = 'F6pkzr49'
# ...

# %%
# %%sh
# sudo apt-get --assume-yes update
# sudo apt-get --assume-yes install freetds-dev freetds-bin
# sudo apt-get --assume-yes install python-dev python-pip
# sudo pip install pymssql
# Out:
# Hit:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:3 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:6 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:7 https://packages.microsoft.com/ubuntu/16.04/prod xenial InRelease
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:10 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:12 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# ...

# %%
#pip install pymysql
import pymysql

# %%
from pymssql import _mssql

# %%
    host=r'H2871513\SQLEXPRESS',
    user=r'H2871513\Administrator',
    password='F6pkzr49',
    database='Semi_Interface'

    print(host)
    print("\\")
# Out:
# ('H2871513\\SQLEXPRESS',)
# \

# %%
conn = pymysql.connect(
    host=r'85.214.143.93',
    user=r'HIRNGESPINSST\Administartor',
    password='Hirngespinsst!',
    database='Semi_Interface',
    Trusted_Connection='yes'
)
print(conn)

cursor = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-b111d8fe9a64> in <module>()
#       7     password='Hirngespinsst!',
#       8     database='Semi_Interface',
# ----> 9     Trusted_Connection='yes'
#      10 )
#      11 print(conn)
#
# TypeError: __init__() got an unexpected keyword argument 'Trusted_Connection'

# %%
# The Cloud SQL Python Connector can be used along with SQLAlchemy using the
# 'creator' argument to 'create_engine'
def init_connection_engine() -> sqlalchemy.engine.Engine:
    def getconn() -> pymysql.connections.Connection:
        conn: pymysql.connections.Connection = connector.connect(
            os.environ["MYSQL_CONNECTION_NAME"],
            "pymysql",
            user=os.environ["MYSQL_USER"],
            password=os.environ["MYSQL_PASS"],
            db=os.environ["MYSQL_DB"],
        )
        return conn

    engine = sqlalchemy.create_engine(
        "mysql+pymysql://",
        creator=getconn,
    )
    return engine
